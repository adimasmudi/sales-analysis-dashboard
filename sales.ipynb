# %%
import pandas as pd

df = pd.read_csv('sales.csv')

df.head()
# Out:
#   Product_Code  W0  W1  W2  W3  W4  W5  W6  W7  W8  ...  Normalized 42  \
# 0           P1  11  12  10   8  13  12  14  21   6  ...           0.06
# 1           P2   7   6   3   2   7   1   6   3   3  ...           0.20
# 2           P3   7  11   8   9  10   8   7  13  12  ...           0.27
# 3           P4  12   8  13   5   9   6   9  13  13  ...           0.41
# 4           P5   8   5  13  11   6   7   9  14   9  ...           0.27
#
#    Normalized 43  Normalized 44  Normalized 45  Normalized 46  Normalized 47  \
# 0           0.22           0.28           0.39           0.50           0.00
# 1           0.40           0.50           0.10           0.10           0.40
# 2           1.00           0.18           0.18           0.36           0.45
# 3           0.47           0.06           0.12           0.24           0.35
# 4           0.53           0.27           0.60           0.20           0.20
#
#    Normalized 48  Normalized 49  Normalized 50  Normalized 51
# ...

# %%
df_new = df.iloc[:,:55]
df_new.head()
# Out:
#   Product_Code  W0  W1  W2  W3  W4  W5  W6  W7  W8  ...  W44  W45  W46  W47  \
# 0           P1  11  12  10   8  13  12  14  21   6  ...    8   10   12    3
# 1           P2   7   6   3   2   7   1   6   3   3  ...    5    1    1    4
# 2           P3   7  11   8   9  10   8   7  13  12  ...    5    5    7    8
# 3           P4  12   8  13   5   9   6   9  13  13  ...    3    4    6    8
# 4           P5   8   5  13  11   6   7   9  14   9  ...    7   12    6    6
#
#    W48  W49  W50  W51  MIN  MAX
# 0    7    6    5   10    3   21
# 1    5    1    6    0    0   10
# 2   14    8    8    7    3   14
# 3   14    8    7    8    2   19
# 4    5   11    8    9    3   18
#
# [5 rows x 55 columns]

# %%
df_new.shape
# Out:
# (811, 55)

# %%
x_label = df_new.columns[1:-2]
x_label
# Out:
# Index(['W0', 'W1', 'W2', 'W3', 'W4', 'W5', 'W6', 'W7', 'W8', 'W9', 'W10',
#        'W11', 'W12', 'W13', 'W14', 'W15', 'W16', 'W17', 'W18', 'W19', 'W20',
#        'W21', 'W22', 'W23', 'W24', 'W25', 'W26', 'W27', 'W28', 'W29', 'W30',
#        'W31', 'W32', 'W33', 'W34', 'W35', 'W36', 'W37', 'W38', 'W39', 'W40',
#        'W41', 'W42', 'W43', 'W44', 'W45', 'W46', 'W47', 'W48', 'W49', 'W50',
#        'W51'],
#       dtype='object')

# %%
from matplotlib import pyplot as plt
import seaborn as sns

sns.lineplot(data=df_new,x='Product_Code',y=x_label)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10952/432069529.py in <module>
#       2 import seaborn as sns
#       3
# ----> 4 sns.scatterplot(data=df_new,x=df_new[x_label],y=df_new[x_label])
#
# c:\Users\ACER\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\Users\ACER\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     806
# ...
